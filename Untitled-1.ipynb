# %%
library(tidyverse)
library(dplyr)


adriandix <- read_csv("csvs/twitterpho/@adriandix_tweets.csv")
AlikaMD <- read_csv("csvs/twitterpho/@AlikaMD_tweets.csv")
AmyGreerKalisz <- read_csv("csvs/twitterpho/@AmyGreerKalisz_tweets.csv")
angie_rasmussen <- read_csv("csvs/twitterpho/@angie_rasmussen_tweets.csv")
AnnaBlakney <- read_csv("csvs/twitterpho/@AnnaBlakney_tweets.csv")
AntibioticDoc <- read_csv("csvs/twitterpho/@AntibioticDoc_tweets.csv")
asapscience <- read_csv("csvs/twitterpho/@asapscience_tweets.csv")
ASPphysician <- read_csv("csvs/twitterpho/@ASPphysician_tweets.csv")
atRachelGilmore <- read_csv("csvs/twitterpho/@atRachelGilmore_tweets.csv")
binhanv <- read_csv("csvs/twitterpho/@binhanv_tweets.csv")
BirinderNarang <- read_csv("csvs/twitterpho/@BirinderNarang_tweets.csv")
blackdocscanada <- read_csv("csvs/twitterpho/@blackdocscanada_tweets.csv")
BogochIsaac <- read_csv("csvs/twitterpho/@BogochIsaac_tweets.csv")
bornk <- read_csv("csvs/twitterpho/@bornk_tweets.csv")
carlyweeks <- read_csv("csvs/twitterpho/@carlyweeks_tweets.csv")
CaulfieldTim <- read_csv("csvs/twitterpho/@CaulfieldTim_tweets.csv")
CDCofBC <- read_csv("csvs/twitterpho/@CDCofBC_tweets.csv")
cdube_sante <- read_csv("csvs/twitterpho/@cdube_sante_tweets.csv")
cfpcceo <- read_csv("csvs/twitterpho/@cfpcceo_tweets.csv")
ChiefSciCan <- read_csv("csvs/twitterpho/@ChiefSciCan_tweets.csv")
cmcovidtf <- read_csv("csvs/twitterpho/@cmcovidtf_tweets.csv")
CMOH_Alberta <- read_csv("csvs/twitterpho/@CMOH_Alberta_tweets.csv")
CMOH_NL <- read_csv("csvs/twitterpho/@CMOH_NL_tweets.csv")
conquercovid19 <- read_csv("csvs/twitterpho/@conquercovid19_tweets.csv")
COVID_19_Canada <- read_csv("csvs/twitterpho/@COVID_19_Canada_tweets.csv")
COVIDSciOntario <- read_csv("csvs/twitterpho/@COVIDSciOntario_tweets.csv")
CPHO_Canada <- read_csv("csvs/twitterpho/@CPHO_Canada_tweets.csv")
ctouzin <- read_csv("csvs/twitterpho/@ctouzin_tweets.csv")
CTV_AvisFavaro <- read_csv("csvs/twitterpho/@CTV_AvisFavaro_tweets.csv")
DeNovo_Fatima <- read_csv("csvs/twitterpho/@DeNovo_Fatima_tweets.csv")
deonandan <- read_csv("csvs/twitterpho/@deonandan_tweets.csv")
drfisman <- read_csv("csvs/twitterpho/@drfisman_tweets.csv")
Dr_ChrisSimpson <- read_csv("csvs/twitterpho/@Dr_ChrisSimpson_tweets.csv")
drgigiosler <- read_csv("csvs/twitterpho/@drgigiosler_tweets.csv")
DrKaliBarrett <- read_csv("csvs/twitterpho/@DrKaliBarrett_tweets.csv")
drmwarner <- read_csv("csvs/twitterpho/@drmwarner_tweets.csv")
drsusanshaw <- read_csv("csvs/twitterpho/@drsusanshaw_tweets.csv")
DrVivianS <- read_csv("csvs/twitterpho/@DrVivianS_tweets.csv")
egpayne <- read_csv("csvs/twitterpho/@egpayne_tweets.csv")
epdevilla <- read_csv("csvs/twitterpho/@epdevilla_tweets.csv")
ErnieHudsonPEI <- read_csv("csvs/twitterpho/@ErnieHudsonPEI_tweets.csv")
everetthindley <- read_csv("csvs/twitterpho/@everetthindley_tweets.csv")
First10EM <- read_csv("csvs/twitterpho/@First10EM_tweets.csv")
GermHunterMD <- read_csv("csvs/twitterpho/@GermHunterMD_tweets.csv")
glenpyle <- read_csv("csvs/twitterpho/@glenpyle_tweets.csv")
heysciencesam <- read_csv("csvs/twitterpho/@heysciencesam_tweets.csv")
hgagneTVA <- read_csv("csvs/twitterpho/@hgagneTVA_tweets.csv")
IDEpiPhD <- read_csv("csvs/twitterpho/@IDEpiPhD_tweets.csv")
imgrund <- read_csv("csvs/twitterpho/@imgrund_tweets.csv")
iPreetBrar <- read_csv("csvs/twitterpho/@iPreetBrar_tweets.csv")
IrfanDhalla <- read_csv("csvs/twitterpho/@IrfanDhalla_tweets.csv")
j_mcelroy <- read_csv("csvs/twitterpho/@j_mcelroy_tweets.csv")
jasonfherring <- read_csv("csvs/twitterpho/@jasonfherring_tweets.csv")
jfrketich <- read_csv("csvs/twitterpho/@jfrketich_tweets.csv")
jkwan_md <- read_csv("csvs/twitterpho/@jkwan_md_tweets.csv")
Johnrockdoc <- read_csv("csvs/twitterpho/@Johnrockdoc_tweets.csv")
JuliaWongCBC <- read_csv("csvs/twitterpho/@JuliaWongCBC_tweets.csv")
juliegreenMLA <- read_csv("csvs/twitterpho/@juliegreenMLA_tweets.csv")
Justin_Ling <- read_csv("csvs/twitterpho/@Justin_Ling_tweets.csv")
jyangstar <- read_csv("csvs/twitterpho/@jyangstar_tweets.csv")
KashPrime <- read_csv("csvs/twitterpho/@KashPrime_tweets.csv")
KatharineSmart <- read_csv("csvs/twitterpho/@KatharineSmart_tweets.csv")
Kevin_Parent <- read_csv("csvs/twitterpho/@Kevin__Parent_tweets.csv")
KindrachuckJason <- read_csv("csvs/twitterpho/@KindrachukJason_tweets.csv")
KrishanaSankar <- read_csv("csvs/twitterpho/@KrishanaSankar_tweets.csv")
kwadwo777 <- read_csv("csvs/twitterpho/@kwadwo777_tweets.csv")
LaurenPelley <- read_csv("csvs/twitterpho/@LaurenPelley_tweets.csv")
LisaBarrettID <- read_csv("csvs/twitterpho/@LisaBarrettID_tweets.csv")
McGillOSS <- read_csv("csvs/twitterpho/@McGillOSS_tweets.csv")
MerrimanPaul <- read_csv("csvs/twitterpho/@MerrimanPaul_tweets.csv")
MichaelSchwandt <- read_csv("csvs/twitterpho/@MichaelSchwandt_tweets.csv")
MLAStefanson <- read_csv("csvs/twitterpho/@MLAStefanson_tweets.csv")
moirawyton <- read_csv("csvs/twitterpho/@moirawyton_tweets.csv")
moriartylabs <- read_csv("csvs/twitterpho/@moriartylabs_tweets.csv")
MPaiMD <- read_csv("csvs/twitterpho/@MPaiMD_tweets.csv")
NaheedD <- read_csv("csvs/twitterpho/@NaheedD_tweets.csv")
NathanStall <- read_csv("csvs/twitterpho/@NathanStall_tweets.csv")
NightShiftMD <- read_csv("csvs/twitterpho/@NightShiftMD_tweets.csv")
NoLore <- read_csv("csvs/twitterpho/@NoLore_tweets.csv")
OttawaHealth <- read_csv("csvs/twitterpho/@OttawaHealth_tweets.csv")
paimadhu <- read_csv("csvs/twitterpho/@paimadhu_tweets.csv")
PattyHajdu <- read_csv("csvs/twitterpho/@PattyHajdu_tweets.csv")
picardonhealth <- read_csv("csvs/twitterpho/@picardonhealth_tweets.csv")
RicharLisa <- read_csv("csvs/twitterpho/@RicharLisa_tweets.csv")
roussin_brent <- read_csv("csvs/twitterpho/@roussin_brent_tweets.csv")
sabaeitizaz <- read_csv("csvs/twitterpho/@sabaeitizaz_tweets.csv")
sabiVM <- read_csv("csvs/twitterpho/@sabiVM_tweets.csv")
SammyG_MD <- read_csv("csvs/twitterpho/@SammyG_MD_tweets.csv")
sarperotto <- read_csv("csvs/twitterpho/@sarperotto_tweets.csv")
SciChefCan <- read_csv("csvs/twitterpho/@SciChefCan_tweets.csv")
sciencemonkeyca <- read_csv("csvs/twitterpho/@sciencemonkeyca_tweets.csv")
ScienceUpFirst <- read_csv("csvs/twitterpho/@ScienceUpFirst_tweets.csv")
sdbaral <- read_csv("csvs/twitterpho/@sdbaral_tweets.csv")
shandro <- read_csv("csvs/twitterpho/@shandro_tweets.csv")
SharkawyMD <- read_csv("csvs/twitterpho/@SharkawyMD_tweets.csv")
shazmamithani <- read_csv("csvs/twitterpho/@shazmamithani_tweets.csv")
ShephardDorothy <- read_csv("csvs/twitterpho/@ShephardDorothy_tweets.csv")
srinmurthy99 <- read_csv("csvs/twitterpho/@srinmurthy99_tweets.csv")
SteiniBrown <- read_csv("csvs/twitterpho/@SteiniBrown_tweets.csv")
theresaboyle <- read_csv("csvs/twitterpho/@theresaboyle_tweets.csv")
thisisourshotca <- read_csv("csvs/twitterpho/@thisisourshotca_tweets.csv")
TorontoIDDOC <- read_csv("csvs/twitterpho/@TorontoIDDOC_tweets.csv")
UbakaOgbogu <- read_csv("csvs/twitterpho/@UbakaOgbogu_tweets.csv")
VaxHuntersCan <- read_csv("csvs/twitterpho/@VaxHuntersCan_tweets.csv")
VeraEtches <- read_csv("csvs/twitterpho/@VeraEtches_tweets.csv")
VikCBC <- read_csv("csvs/twitterpho/@VikCBC_tweets.csv")
wickdchiq <- read_csv("csvs/twitterpho/@wickdchiq_tweets.csv")
zachchurchhill <- read_csv("csvs/twitterpho/@zachchurchill_tweets.csv")
zchangla <- read_csv("csvs/twitterpho/@zchagla_tweets.csv")
DrKathleenRoss1 <- read_csv("csvs/twitterpho/DrKathleenRoss1_tweets.csv")
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4     v readr     2.1.5
# v forcats   1.0.0     v stringr   1.5.0
# v ggplot2   3.4.2     v tibble    3.2.1
# v lubridate 1.9.3     v tidyr     1.3.1
# v purrr     1.0.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 358751 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, edit_history_tweet_ids, author_id, conversation_id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 44622 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 22665 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 210149 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, conversation_id, edit_history_tweet_id...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1265 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, entities, edit_history_tweet_ids, attachments, clean_text, ...
# dbl  (11): ...1, conversation_id, author_id, in_reply_to_user_id, id, public...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 47293 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, id, author_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 2729 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, conversation_id, edit_history_tweet_id...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 39004 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 781987 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, lang, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, id, in_reply_to_user_id, edit_history_tweet_ids,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 615 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 27025 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, in_reply_to_user_id, author_id,...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 2181 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 264677 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 607 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 20959 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, attachments, entities, withheld, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, author_id, con...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 198075 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, author_id, conversation_id, edit_histo...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 92290 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, edit_history_tweet_ids, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 390441 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, in_reply_to_user_id, edit_history_twee...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1627 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, author_id, id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 6946 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, edit_history_tweet_ids, entities, attachments, clean_text, ...
# dbl  (11): ...1, conversation_id, in_reply_to_user_id, id, author_id, public...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 359 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 197300 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, edit_history_tweet_ids, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 14254 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, edit_history_tweet_ids, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 432 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 22794 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, id, in_reply_to_user_id, edit_history_tweet_ids,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 75625 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 364151 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 479 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, in_reply_to_user_id, author_id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 8253 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 22786 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, edit_history_tweet_ids, author_id, id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 88456 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, id, author_id, in_reply_to_user_id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 2 Columns: 19
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, lang, text, clean_text, sentiment, emojis
# dbl  (11): ...1, author_id, conversation_id, id, edit_history_tweet_ids, pub...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1520 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 3556 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 6704 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, in_reply_to_user_id, conversation_id, author_id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 200685 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, edit_history_tweet_ids, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 5067 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, in_reply_to_user_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 224550 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 29788 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, author_id, edit_history_tweet_ids, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 49278 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, author_id, conversation_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1265 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, in_reply_to_user_id, conversation_id, author_id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 3540 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, in_reply_to_user_id, edit_history_tweet_ids, author_id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 25226 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, author_id, edit_history_tweet_ids, id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 37777 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): entities, lang, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 24456 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, author_id, conversation_id, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 11749 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, author_id, conversation_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1329 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, id, in_reply_to_user_id, edit_history_tweet_ids,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 22295 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, author_id, in_reply_to_user_id, id, edit_h...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 425704 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, id, conversation_id, author_id, edit_h...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 250 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, entities, attachments, withheld, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 94144 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 154448 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, in_reply_to_user_id, author_id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 9297 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 12948 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 80877 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, author_id, conversation_id, edit_histo...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 9554 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 7704 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, lang, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, in_reply_to_user_id, edit_histo...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 839 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, author_id, id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 388356 Columns: 22
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (8): lang, text, entities, attachments, withheld, clean_text, sentimen...
# dbl  (12): ...1, author_id, in_reply_to_user_id, conversation_id, id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 5790 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, author_id, conversation_id, edit_histo...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 236554 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 89943 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, author_id, conversation_id, edit_histo...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 3040 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, in_reply_to_user_id, author_id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 24810 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, edit_history_tweet_ids, author_id, id,...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 8106 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 72909 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 46099 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 26461 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): attachments, entities, text, clean_text, sentiment, emojis
# dbl  (12): ...1, id, in_reply_to_user_id, edit_history_tweet_ids, author_id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 6227 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, id, conversation_id, author_id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 6543 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, id, edit_history_tweet_ids, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 13250 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 206 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, id, edit_history_tweet_ids, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 12757 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, in_reply_to_user_id, conversation_id, author_id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 25 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (5): entities, text, lang, clean_text, sentiment
# dbl  (12): ...1, author_id, edit_history_tweet_ids, conversation_id, id, in_...
# lgl   (2): possibly_sensitive, emojis
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 11638 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 577263 Columns: 22
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): entities, text, lang, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, author_id, conversation_id, edit_history_tweet_ids, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 88153 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 384208 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, author_id, id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 163427 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, edit_history_tweet_ids, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 155827 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 150744 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): text, entities, attachments, withheld, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 67973 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 259530 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, author_id, in_reply_to_user_id, id, edit_h...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 43901 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, id, author_id, in_reply_to_user_id, edit_h...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 20253 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, author_id, conversation_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 18530 Columns: 22
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): entities, text, lang, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, edit_history_tweet_ids, author_id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 74776 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, in_reply_to_user_id, author_id,...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 11005 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, author_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 6339 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, conversation_id, edit_history_tweet_id...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1858 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, id, author_id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 15491 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 40030 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 134195 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, in_reply_to_user_id, id, conversation_id, author_id, edit_h...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 52541 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 136700 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): attachments, text, entities, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, conversation_id, author_id, id, in_...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 41633 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, author_id, conversation_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 11947 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, in_reply_to_user_id, edit_history_twee...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 2352 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, author_id, id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 8520 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, in_reply_to_user_id, edit_history_tweet_ids, author_id,...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 23899 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, edit_history_tweet_ids, id, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 6337 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, author_id, con...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 28293 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 213617 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, conversation_id, edit_history_tweet_ids, id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 39042 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, attachments, text, clean_text, sentiment, emojis
# dbl  (12): ...1, id, conversation_id, edit_history_tweet_ids, author_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 44669 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, author_id, edit_history_tweet_ids, id, conversation_id, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 1578 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, conversation_id, id, author_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 150151 Columns: 22
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (8): edit_history_tweet_ids, lang, entities, text, attachments, clean_...
# dbl  (11): ...1, author_id, in_reply_to_user_id, conversation_id, id, public...
# lgl   (2): possibly_sensitive, withheld
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 8729 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): entities, text, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, edit_history_tweet_ids, in_reply_to_user_id, conversation_i...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 52902 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (6): text, entities, attachments, clean_text, sentiment, emojis
# dbl  (12): ...1, id, author_id, conversation_id, edit_history_tweet_ids, in_...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# * `` -> `...1`
# Rows: 7578 Columns: 20
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (7): edit_history_tweet_ids, entities, text, attachments, clean_text, ...
# dbl  (11): ...1, author_id, conversation_id, id, in_reply_to_user_id, public...
# lgl   (1): possibly_sensitive
# dttm  (1): created_at
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
adriandix_count <- count(adriandix)
AlikaMD_count <- count(AlikaMD)
AmyGreerKalisz_count <- count(AmyGreerKalisz)
angie_rasmussen_count <- count(angie_rasmussen)
AnnaBlakney_count <- count(AnnaBlakney)
AntibioticDoc_count <- count(AntibioticDoc)
asapscience_count <- count(asapscience)
ASPphysician_count <- count(ASPphysician)
atRachelGilmore_count <- count(atRachelGilmore)
binhanv_count <- count(binhanv)
BirinderNarang_count <- count(BirinderNarang)
blackdocscanada_count <- count(blackdocscanada)
BogochIsaac_count <- count(BogochIsaac)
bornk_count <- count(bornk)
carlyweeks_count <- count(carlyweeks)
CaulfieldTim_count <- count(CaulfieldTim)
CDCofBC_count <- count(CDCofBC)
cdube_sante_count <- count(cdube_sante)
cfpcceo_count <- count(cfpcceo)
ChiefSciCan_count <- count(ChiefSciCan)
cmcovidtf_count <- count(cmcovidtf)
CMOH_Alberta_count <- count(CMOH_Alberta)
CMOH_NL_count <- count(CMOH_NL)
conquercovid19_count <- count(conquercovid19)
COVID_19_Canada_count <- count(COVID_19_Canada)
COVIDSciOntario_count <- count(COVIDSciOntario)
CPHO_Canada_count <- count(CPHO_Canada)
ctouzin_count <- count(ctouzin)
CTV_AvisFavaro_count <- count(CTV_AvisFavaro)
DeNovo_Fatima_count <- count(DeNovo_Fatima)
deonandan_count <- count(deonandan)
drfisman_count <- count(drfisman)
Dr_ChrisSimpson_count <- count(Dr_ChrisSimpson)
drgigiosler_count <- count(drgigiosler)
DrKaliBarrett_count <- count(DrKaliBarrett)
drmwarner_count <- count(drmwarner)
drsusanshaw_count <- count(drsusanshaw)
DrVivianS_count <- count(DrVivianS)
egpayne_count <- count(egpayne)
epdevilla_count <- count(epdevilla)
ErnieHudsonPEI_count <- count(ErnieHudsonPEI)
everetthindley_count <- count(everetthindley)
First10EM_count <- count(First10EM)
GermHunterMD_count <- count(GermHunterMD)
glenpyle_count <- count(glenpyle)
heysciencesam_count <- count(heysciencesam)
hgagneTVA_count <- count(hgagneTVA)
IDEpiPhD_count <- count(IDEpiPhD)
imgrund_count <- count(imgrund)
iPreetBrar_count <- count(iPreetBrar)
IrfanDhalla_count <- count(IrfanDhalla)
j_mcelroy_count <- count(j_mcelroy)
jasonfherring_count <- count(jasonfherring)
jfrketich_count <- count(jfrketich)
jkwan_md_count <- count(jkwan_md)
Johnrockdoc_count <- count(Johnrockdoc)
JuliaWongCBC_count <- count(JuliaWongCBC)
juliegreenMLA_count <- count(juliegreenMLA)
Justin_Ling_count <- count(Justin_Ling)
jyangstar_count <- count(jyangstar)
KashPrime_count <- count(KashPrime)
KatharineSmart_count <- count(KatharineSmart)
Kevin_Parent_count <- count(Kevin_Parent)
KindrachuckJason_count <- count(KindrachuckJason)
KrishanaSankar_count <- count(KrishanaSankar)
kwadwo777_count <- count(kwadwo777)
LaurenPelley_count <- count(LaurenPelley)
LisaBarrettID_count <- count(LisaBarrettID)
McGillOSS_count <- count(McGillOSS)
MerrimanPaul_count <- count(MerrimanPaul)
MichaelSchwandt_count <- count(MichaelSchwandt)
MLAStefanson_count <- count(MLAStefanson)
moirawyton_count <- count(moirawyton)
moriartylabs_count <- count(moriartylabs)
MPaiMD_count <- count(MPaiMD)
NaheedD_count <- count(NaheedD)
NathanStall_count <- count(NathanStall)
NightShiftMD_count <- count(NightShiftMD)
NoLore_count <- count(NoLore)
OttawaHealth_count <- count(OttawaHealth)
paimadhu_count <- count(paimadhu)
PattyHajdu_count <- count(PattyHajdu)
picardonhealth_count <- count(picardonhealth)
RicharLisa_count <- count(RicharLisa)
roussin_brent_count <- count(roussin_brent)
sabaeitizaz_count <- count(sabaeitizaz)
sabiVM_count <- count(sabiVM)
SammyG_MD_count <- count(SammyG_MD)
sarperotto_count <- count(sarperotto)
SciChefCan_count <- count(SciChefCan)
sciencemonkeyca_count <- count(sciencemonkeyca)
ScienceUpFirst_count <- count(ScienceUpFirst)
sdbaral_count <- count(sdbaral)
shandro_count <- count(shandro)
SharkawyMD_count <- count(SharkawyMD)
shazmamithani_count <- count(shazmamithani)
ShephardDorothy_count <- count(ShephardDorothy)
srinmurthy99_count <- count(srinmurthy99)
SteiniBrown_count <- count(SteiniBrown)
theresaboyle_count <- count(theresaboyle)
thisisourshotca_count <- count(thisisourshotca)
TorontoIDDOC_count <- count(TorontoIDDOC)
UbakaOgbogu_count <- count(UbakaOgbogu)
VaxHuntersCan_count <- count(VaxHuntersCan)
VeraEtches_count <- count(VeraEtches)
VikCBC_count <- count(VikCBC)
wickdchiq_count <- count(wickdchiq)
zachchurchhill_count <- count(zachchurchhill)
zchangla_count <- count(zchangla)
DrKathleenRoss1_count <- count(DrKathleenRoss1)

# %%
merged_tweets <- read_csv("merged_tweets.csv")
# Out:
# Rows: 8750054 Columns: 2
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (1): text
# dbl (1): source
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# Create a data frame with the counts
tweet_counts <- data.frame(
  User = c("adriandix", "AlikaMD", "AmyGreerKalisz", "angie_rasmussen", "AnnaBlakney", "AntibioticDoc", 
           "asapscience", "ASPphysician", "atRachelGilmore", "binhanv", "BirinderNarang", 
           "blackdocscanada", "BogochIsaac", "bornk", "carlyweeks", "CaulfieldTim", "CDCofBC", 
           "cdube_sante", "cfpcceo", "ChiefSciCan", "cmcovidtf", "CMOH_Alberta", "CMOH_NL", 
           "conquercovid19", "COVID_19_Canada", "COVIDSciOntario", "CPHO_Canada", "ctouzin", 
           "CTV_AvisFavaro", "DeNovo_Fatima", "deonandan", "drfisman", "Dr_ChrisSimpson", 
           "drgigiosler", "DrKaliBarrett", "drmwarner", "drsusanshaw", "DrVivianS", "egpayne", 
           "epdevilla", "ErnieHudsonPEI", "everetthindley", "First10EM", "GermHunterMD", "glenpyle", 
           "heysciencesam", "hgagneTVA", "IDEpiPhD", "imgrund", "iPreetBrar", "IrfanDhalla", 
           "j_mcelroy", "jasonfherring", "jfrketich", "jkwan_md", "Johnrockdoc", "JuliaWongCBC", 
           "juliegreenMLA", "Justin_Ling", "jyangstar", "KashPrime", "KatharineSmart", "Kevin_Parent", 
           "KindrachuckJason", "KrishanaSankar", "kwadwo777", "LaurenPelley", "LisaBarrettID", 
           "McGillOSS", "MerrimanPaul", "MichaelSchwandt", "MLAStefanson", "moirawyton", 
           "moriartylabs", "MPaiMD", "NaheedD", "NathanStall", "NightShiftMD", "NoLore", 
           "OttawaHealth", "paimadhu", "PattyHajdu", "picardonhealth", "RicharLisa", "roussin_brent", 
           "sabaeitizaz", "sabiVM", "SammyG_MD", "sarperotto", "SciChefCan", "sciencemonkeyca", 
           "ScienceUpFirst", "sdbaral", "shandro", "SharkawyMD", "shazmamithani", "ShephardDorothy", 
           "srinmurthy99", "SteiniBrown", "theresaboyle", "thisisourshotca", "TorontoIDDOC", 
           "UbakaOgbogu", "VaxHuntersCan", "VeraEtches", "VikCBC", "wickdchiq", "zachchurchhill", 
           "zchangla", "DrKathleenRoss1"),
  Count = c(nrow(adriandix), nrow(AlikaMD), nrow(AmyGreerKalisz), nrow(angie_rasmussen), 
            nrow(AnnaBlakney), nrow(AntibioticDoc), nrow(asapscience), nrow(ASPphysician), 
            nrow(atRachelGilmore), nrow(binhanv), nrow(BirinderNarang), nrow(blackdocscanada), 
            nrow(BogochIsaac), nrow(bornk), nrow(carlyweeks), nrow(CaulfieldTim), nrow(CDCofBC), 
            nrow(cdube_sante), nrow(cfpcceo), nrow(ChiefSciCan), nrow(cmcovidtf), nrow(CMOH_Alberta), 
            nrow(CMOH_NL), nrow(conquercovid19), nrow(COVID_19_Canada), nrow(COVIDSciOntario), 
            nrow(CPHO_Canada), nrow(ctouzin), nrow(CTV_AvisFavaro), nrow(DeNovo_Fatima), 
            nrow(deonandan), nrow(drfisman), nrow(Dr_ChrisSimpson), nrow(drgigiosler), 
            nrow(DrKaliBarrett), nrow(drmwarner), nrow(drsusanshaw), nrow(DrVivianS), nrow(egpayne), 
            nrow(epdevilla), nrow(ErnieHudsonPEI), nrow(everetthindley), nrow(First10EM), 
            nrow(GermHunterMD), nrow(glenpyle), nrow(heysciencesam), nrow(hgagneTVA), nrow(IDEpiPhD), 
            nrow(imgrund), nrow(iPreetBrar), nrow(IrfanDhalla), nrow(j_mcelroy), nrow(jasonfherring), 
            nrow(jfrketich), nrow(jkwan_md), nrow(Johnrockdoc), nrow(JuliaWongCBC), nrow(juliegreenMLA), 
            nrow(Justin_Ling), nrow(jyangstar), nrow(KashPrime), nrow(KatharineSmart), nrow(Kevin_Parent), 
            nrow(KindrachuckJason), nrow(KrishanaSankar), nrow(kwadwo777), nrow(LaurenPelley), 
            nrow(LisaBarrettID), nrow(McGillOSS), nrow(MerrimanPaul), nrow(MichaelSchwandt), 
            nrow(MLAStefanson), nrow(moirawyton), nrow(moriartylabs), nrow(MPaiMD), nrow(NaheedD), 
            nrow(NathanStall), nrow(NightShiftMD), nrow(NoLore), nrow(OttawaHealth), nrow(paimadhu), 
            nrow(PattyHajdu), nrow(picardonhealth), nrow(RicharLisa), nrow(roussin_brent), 
            nrow(sabaeitizaz), nrow(sabiVM), nrow(SammyG_MD), nrow(sarperotto), nrow(SciChefCan), 
            nrow(sciencemonkeyca), nrow(ScienceUpFirst), nrow(sdbaral), nrow(shandro), nrow(SharkawyMD), 
            nrow(shazmamithani), nrow(ShephardDorothy), nrow(srinmurthy99), nrow(SteiniBrown), 
            nrow(theresaboyle), nrow(thisisourshotca), nrow(TorontoIDDOC), nrow(UbakaOgbogu), 
            nrow(VaxHuntersCan), nrow(VeraEtches), nrow(VikCBC), nrow(wickdchiq), nrow(zachchurchhill), 
            nrow(zchangla), nrow(DrKathleenRoss1))
)

# Calculate total number of tweets
total_tweets <- sum(tweet_counts$Count)

# Add a column for the proportion of tweets
tweet_counts <- tweet_counts %>%
  mutate(percentage = Count / total_tweets*100)

# View the dataset
write_csv(tweet_counts, "NFRF_user_counts.csv")

# %%
tweet_counts
# Out:
#     User            Count  percentage
# 1   adriandix       358751 4.099986126
# 2   AlikaMD          44622 0.509962567
# 3   AmyGreerKalisz   22665 0.259026973
# 4   angie_rasmussen 210149 2.401688035
# 5   AnnaBlakney       1265 0.014457054
# 6   AntibioticDoc    47293 0.540488093
# 7   asapscience       2729 0.031188379
# 8   ASPphysician     39004 0.445757249
# 9   atRachelGilmore 781987 8.936939132
# 10  binhanv            615 0.007028528
# 11  BirinderNarang   27025 0.308855237
# 12  blackdocscanada   2181 0.024925560
# 13  BogochIsaac     264677 3.024861332
# 14  bornk              607 0.006937100
# 15  carlyweeks       20959 0.239529950
# 16  CaulfieldTim    198075 2.263700315
# 17  CDCofBC          92290 1.054736348
# 18  cdube_sante     390441 4.462155319
# 19  cfpcceo           1627 0.018594171
# 20  ChiefSciCan       6946 0.079382367
# 21  cmcovidtf          359 0.004102832
# 22  CMOH_Alberta    197300 2.254843227
# 23  CMOH_NL          14254 0.162901852
# 24  conquercovid19     432 0.004937112
# 25  COVID_19_Canada  22794 0.260501249
# 26  COVIDSciOntario  75625 0.864280380
# 27  CPHO_Canada     364151 4.161700031
# 28  ctouzin            479 0.005474252
# 29  CTV_AvisFavaro    8253 0.094319418
# 30  DeNovo_Fatima    22786 0.260409821
# ... ...             ...    ...
# 81  paimadhu        150744 1.72277794
# 82  PattyHajdu       67973 0.77682949
# 83  picardonhealth  259530 2.96603884
# 84  RicharLisa       43901 0.50172262
# 85  roussin_brent    20253 0.23146143
# 86  sabaeitizaz      18530 0.21177012
# 87  sabiVM           74776 0.85457758
# 88  SammyG_MD        11005 0.12577065
# 89  sarperotto        6339 0.07244527
# 90  SciChefCan        1858 0.02123415
# 91  sciencemonkeyca  15491 0.17703891
# 92  ScienceUpFirst   40030 0.45748289
# 93  sdbaral         134195 1.53364768
# 94  shandro          52541 0.60046487
# 95  SharkawyMD      136700 1.56227607
# 96  shazmamithani    41633 0.47580278
# 97  ShephardDorothy  11947 0.13653630
# 98  srinmurthy99      2352 0.02687983
# 99  SteiniBrown       8520 0.09737083
# 100 theresaboyle     23899 0.27312974
# 101 thisisourshotca   6337 0.07242241
# 102 TorontoIDDOC     28293 0.32334658
# 103 UbakaOgbogu     213617 2.44132208
# 104 VaxHuntersCan    39042 0.44619153
# 105 VeraEtches       44669 0.51049971
# 106 VikCBC            1578 0.01803417
# 107 wickdchiq       150151 1.71600084
# 108 zachchurchhill    8729 0.09975938
# 109 zchangla         52902 0.60459055
# 110 DrKathleenRoss1   7578 0.08660518

# %%
health_communicators <- read_csv("health_communicators.csv")

health_communicators_male <- health_communicators %>%
  filter(Gender == "M") %>%
  select(Handle) %>%
  mutate(Handle = gsub("@", "", Handle)) %>%
  pull(Handle)

health_communicators_female <- health_communicators %>%
  filter(Gender == "W") %>%
  select(Handle) %>%
  mutate(Handle = gsub("@", "", Handle)) %>%
  pull(Handle)

health_communicators_org <- health_communicators %>%
  filter(Gender == "O") %>%
  select(Handle) %>%
  mutate(Handle = gsub("@", "", Handle)) %>%
  pull(Handle)

# %%
women <- list(AmyGreerKalisz, angie_rasmussen, AnnaBlakney, AntibioticDoc, binhanv, bornk, carlyweeks, ChiefSciCan, CMOH_Alberta, CMOH_NL, CPHO_Canada, ctouzin, CTV_AvisFavaro, DeNovo_Fatima, drgigiosler, DrKaliBarrett, drsusanshaw, DrVivianS, egpayne, epdevilla, glenpyle, heysciencesam, IDEpiPhD, iPreetBrar, jfrketich, jkwan_md, JuliaWongCBC, juliegreenMLA, jyangstar, KatharineSmart, KrishanaSankar, LaurenPelley, LisaBarrettID, MLAStefanson, moriartylabs, moirawyton, MPaiMD, NoLore, PattyHajdu, RicharLisa, sabiVM, SciChefCan, sarperotto, shazmamithani, ShephardDorothy, theresaboyle, VeraEtches, wickdchiq, DrKathleenRoss1)
result <- lapply(women, function(df) df[, "text", drop = FALSE])
merged_df <- bind_rows(result, .id = "source")
write_csv(merged_df, "merged_tweets_women.csv")

men <- list(adriandix, AlikaMD, ASPphysician, BogochIsaac, CaulfieldTim, cdube_sante, deonandan, Dr_ChrisSimpson, drfisman, drmwarner, ErnieHudsonPEI, everetthindley, First10EM, GermHunterMD, imgrund, IrfanDhalla, j_mcelroy, jasonfherring, Johnrockdoc, Justin_Ling, KashPrime, Kevin_Parent, KindrachuckJason, kwadwo777, MerrimanPaul, NaheedD, NathanStall, NightShiftMD, paimadhu, picardonhealth, roussin_brent, SammyG_MD, sciencemonkeyca, sdbaral, shandro, srinmurthy99, SteiniBrown, TorontoIDDOC, UbakaOgbogu, VikCBC, zachchurchhill, zchangla)
result_men <- lapply(men, function(df) df[, "text", drop = FALSE])
merged_df_men <- bind_rows(result_men, .id = "source")
write_csv(merged_df_men, "merged_tweets_women.csv")

# %%
terms <- c("fuck", "dirty", "stupid", "idiot", "asshole", "bastard", "nasty", "whore", "slut", "skank", "cunt", "bitch", "motherfucker", "go to hell", "wimp", "coward", "moron", "traitor", "shut up", "shut the fuck up", "stfu", "piece of shit", "ignorant", "clown", "ccpvirus", "chinese coronavirus", "chinavirus", "china virus", "fuckchina", "nukechina", "bombchina", "deathtochina", "chinesevirus", "fake lab wuhan", "china weapon", "china bioweapon", "zionazi", "Soros virus", "blood libel", "nwovirus", "new world order", "sacrifice children", "jew world order", "liar", "yellow star", "israel virus", "israelvirus", "rothschild covid", "kalergi plan", "jail", "locked up", "evil.", "is evil", "so evil", "pure evil", "an evil", "evil wom", "evil man", "evil witch", "is evil", "are evil", "that evil", "very evil", "tyrant", "tyranny", "dictator", "tv doctor", "twitter doctor", "murder", "murderer", "eugenic", "satan", "Nazi", "non-human", "sterile", "slave", "crooked", "corrupt", "shill", "liar", "lying", "killer", "fraud", "big pharma", "pharma puppet", "Nuremberg", "crimes against humanity", "genocide", "child abuse", "covid hoax", "covid fake", "virus hoax", "gates virus", "bioweapon", "secret elite", "depopulation", "save our children", "scamdemic", "plandemic")
terms <- paste0(" ", terms)

# %%
pattern <- paste(terms, collapse = "|")

male_info <- merged_df_men |>
  mutate(negative = as.integer(grepl(pattern, text, ignore.case = TRUE)))
female_info <- merged_df |>
  mutate(negative = as.integer(grepl(pattern, text, ignore.case = TRUE)))

male_neg <- male_info |>
  filter(negative == 1)

female_neg <- female_info |>
  filter(negative == 1)

# %%
count(female_neg)

# %%
counts <- tibble(
  negative = c(148501, 75842),
  total = c(5088774, 2236959),
  gender = c("male", "female")
)

# %%
counts_standardized <- counts |>
    mutate(negative = negative / total) |>
    mutate(total = 1)
counts

# %%
ggplot(counts, aes(x = gender)) +
     geom_bar(aes(y = total, fill = "Total"), stat = "identity", color = "black", alpha = 0.5) +
     geom_bar(aes(y = negative, fill = "Negative"), stat = "identity", color = "black") +
     scale_fill_manual(values = c("Total" = "lightblue", "Negative" = "red")) +
     labs(
          title = "Proportion of Negative Cases by Gender",
          x = "Gender",
          y = "Proportion of Total (normalized)"
     ) +
     theme_minimal() +
     theme(legend.position = "bottom", legend.title = element_blank())

# %%
sentiment <- x |>
  select(text)
mutate(negative = as.integer(grepl(pattern, text, ignore.case = TRUE)))

# %%
# Your original list of datasets with their names
list <- list(adriandix, AlikaMD, AmyGreerKalisz)
pattern <- paste(terms, collapse = "|")

# Function to apply the transformation
transform_data <- function(df) {
  df %>%
    select(text) %>%
    mutate(negative = as.integer(grepl(pattern, text, ignore.case = TRUE)))
}

# Apply the transformation to each dataset in the list
transformed_list <- lapply(list, transform_data)

# Assign the names of the datasets to the transformed list
names(transformed_list) <- c("adriandix", "AlikaMD", "AmyGreerKalisz")

# %%
# Your original list of datasets with their names
df_list <- list(
  adriandix, AlikaMD, AmyGreerKalisz, angie_rasmussen, AnnaBlakney, AntibioticDoc,
  asapscience, ASPphysician, atRachelGilmore, binhanv, BirinderNarang, blackdocscanada,
  BogochIsaac, bornk, carlyweeks, CaulfieldTim, CDCofBC, cdube_sante, cfpcceo, ChiefSciCan,
  cmcovidtf, CMOH_Alberta, CMOH_NL, conquercovid19, COVID_19_Canada, COVIDSciOntario,
  CPHO_Canada, ctouzin, CTV_AvisFavaro, DeNovo_Fatima, deonandan, drfisman, Dr_ChrisSimpson,
  drgigiosler, DrKaliBarrett, drmwarner, drsusanshaw, DrVivianS, egpayne, epdevilla, ErnieHudsonPEI,
  everetthindley, First10EM, GermHunterMD, glenpyle, heysciencesam, hgagneTVA, IDEpiPhD, imgrund,
  iPreetBrar, IrfanDhalla, j_mcelroy, jasonfherring, jfrketich, jkwan_md, Johnrockdoc, JuliaWongCBC,
  juliegreenMLA, Justin_Ling, jyangstar, KashPrime, KatharineSmart, Kevin_Parent, KindrachuckJason,
  KrishanaSankar, kwadwo777, LaurenPelley, LisaBarrettID, McGillOSS, MerrimanPaul, MichaelSchwandt,
  MLAStefanson, moirawyton, moriartylabs, MPaiMD, NaheedD, NathanStall, NightShiftMD, NoLore, OttawaHealth,
  paimadhu, PattyHajdu, picardonhealth, RicharLisa, roussin_brent, sabaeitizaz, sabiVM, SammyG_MD,
  sarperotto, SciChefCan, sciencemonkeyca, ScienceUpFirst, sdbaral, shandro, SharkawyMD, shazmamithani,
  ShephardDorothy, srinmurthy99, SteiniBrown, theresaboyle, thisisourshotca, TorontoIDDOC, UbakaOgbogu,
  VaxHuntersCan, VeraEtches, VikCBC, wickdchiq, zachchurchhill, zchangla, DrKathleenRoss1
)

pattern <- paste(terms, collapse = "|")

# Function to apply the transformation
transform_data <- function(df) {
  df %>%
    select(text) %>%
    mutate(negative = as.integer(grepl(pattern, text, ignore.case = TRUE)))
}

# Apply the transformation to each dataset in the list
transformed_list <- lapply(df_list, transform_data)

# Assign the names of the datasets to the transformed list
names(transformed_list) <- c("adriandix", "AlikaMD", "AmyGreerKalisz", "angie_rasmussen", "AnnaBlakney", 
                             "AntibioticDoc", "asapscience", "ASPphysician", "atRachelGilmore", "binhanv", 
                             "BirinderNarang", "blackdocscanada", "BogochIsaac", "bornk", "carlyweeks", 
                             "CaulfieldTim", "CDCofBC", "cdube_sante", "cfpcceo", "ChiefSciCan", "cmcovidtf", 
                             "CMOH_Alberta", "CMOH_NL", "conquercovid19", "COVID_19_Canada", "COVIDSciOntario", 
                             "CPHO_Canada", "ctouzin", "CTV_AvisFavaro", "DeNovo_Fatima", "deonandan", "drfisman", 
                             "Dr_ChrisSimpson", "drgigiosler", "DrKaliBarrett", "drmwarner", "drsusanshaw", 
                             "DrVivianS", "egpayne", "epdevilla", "ErnieHudsonPEI", "everetthindley", "First10EM", 
                             "GermHunterMD", "glenpyle", "heysciencesam", "hgagneTVA", "IDEpiPhD", "imgrund", 
                             "iPreetBrar", "IrfanDhalla", "j_mcelroy", "jasonfherring", "jfrketich", "jkwan_md", 
                             "Johnrockdoc", "JuliaWongCBC", "juliegreenMLA", "Justin_Ling", "jyangstar", "KashPrime", 
                             "KatharineSmart", "Kevin_Parent", "KindrachuckJason", "KrishanaSankar", "kwadwo777", 
                             "LaurenPelley", "LisaBarrettID", "McGillOSS", "MerrimanPaul", "MichaelSchwandt", 
                             "MLAStefanson", "moirawyton", "moriartylabs", "MPaiMD", "NaheedD", "NathanStall", 
                             "NightShiftMD", "NoLore", "OttawaHealth", "paimadhu", "PattyHajdu", "picardonhealth", 
                             "RicharLisa", "roussin_brent", "sabaeitizaz", "sabiVM", "SammyG_MD", "sarperotto", 
                             "SciChefCan", "sciencemonkeyca", "ScienceUpFirst", "sdbaral", "shandro", "SharkawyMD", 
                             "shazmamithani", "ShephardDorothy", "srinmurthy99", "SteiniBrown", "theresaboyle", 
                             "thisisourshotca", "TorontoIDDOC", "UbakaOgbogu", "VaxHuntersCan", "VeraEtches", 
                             "VikCBC", "wickdchiq", "zachchurchhill", "zchangla", "DrKathleenRoss1")

# Use list2env to assign each element of transformed_list to a variable in the global environment
list2env(transformed_list, envir = .GlobalEnv)

# %%
#this cell applies a bunch of transformations to each dataset so will take a while to run (~20 min)
#there are likely faster ways of doing this but this is what I figured out

pattern <- paste(terms, collapse = "|")

# Function that finds harassment terms and calculates proportion 
transform_data <- function(df) {
  total_entries <- nrow(df) #getting total n of entries in each df in order to calculate proportion
  
  # Select the text column and create the 'negative' column: value of 0 if does not contain an entry in the list, of terms, value of 1 if it does.
  df <- df %>%
    select(text) %>%
    mutate(negative = as.integer(grepl(pattern, text, ignore.case = TRUE)))


  negative_entries <- nrow(df |> filter(negative == 1))

  df <- df %>% #getting the proportion of harrassment tweets relative to the entire df, for each df
    mutate(proportion_negative = negative_entries / total_entries)|>
    select(proportion_negative)|>
    head(1)|>
    as.list()
  
  return(df)
}

# Applying function defined above using lapply
transformed_list <- lapply(df_list, transform_data)

#side-effect of using this function is that for some reason it converts the name of each df to an integer; 
#converting the names of each dataset from integer values back to the original names using list2env
names(transformed_list) <- c("adriandix", "AlikaMD", "AmyGreerKalisz", "angie_rasmussen", "AnnaBlakney", 
                             "AntibioticDoc", "asapscience", "ASPphysician", "atRachelGilmore", "binhanv", 
                             "BirinderNarang", "blackdocscanada", "BogochIsaac", "bornk", "carlyweeks", 
                             "CaulfieldTim", "CDCofBC", "cdube_sante", "cfpcceo", "ChiefSciCan", "cmcovidtf", 
                             "CMOH_Alberta", "CMOH_NL", "conquercovid19", "COVID_19_Canada", "COVIDSciOntario", 
                             "CPHO_Canada", "ctouzin", "CTV_AvisFavaro", "DeNovo_Fatima", "deonandan", "drfisman", 
                             "Dr_ChrisSimpson", "drgigiosler", "DrKaliBarrett", "drmwarner", "drsusanshaw", 
                             "DrVivianS", "egpayne", "epdevilla", "ErnieHudsonPEI", "everetthindley", "First10EM", 
                             "GermHunterMD", "glenpyle", "heysciencesam", "hgagneTVA", "IDEpiPhD", "imgrund", 
                             "iPreetBrar", "IrfanDhalla", "j_mcelroy", "jasonfherring", "jfrketich", "jkwan_md", 
                             "Johnrockdoc", "JuliaWongCBC", "juliegreenMLA", "Justin_Ling", "jyangstar", "KashPrime", 
                             "KatharineSmart", "Kevin_Parent", "KindrachuckJason", "KrishanaSankar", "kwadwo777", 
                             "LaurenPelley", "LisaBarrettID", "McGillOSS", "MerrimanPaul", "MichaelSchwandt", 
                             "MLAStefanson", "moirawyton", "moriartylabs", "MPaiMD", "NaheedD", "NathanStall", 
                             "NightShiftMD", "NoLore", "OttawaHealth", "paimadhu", "PattyHajdu", "picardonhealth", 
                             "RicharLisa", "roussin_brent", "sabaeitizaz", "sabiVM", "SammyG_MD", "sarperotto", 
                             "SciChefCan", "sciencemonkeyca", "ScienceUpFirst", "sdbaral", "shandro", "SharkawyMD", 
                             "shazmamithani", "ShephardDorothy", "srinmurthy99", "SteiniBrown", "theresaboyle", 
                             "thisisourshotca", "TorontoIDDOC", "UbakaOgbogu", "VaxHuntersCan", "VeraEtches", 
                             "VikCBC", "wickdchiq", "zachchurchhill", "zchangla", "DrKathleenRoss1")

list2env(transformed_list, envir = .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %%
df_list <- list(
    adriandix, AlikaMD, AmyGreerKalisz
)

merged_df <- bind_rows(df_list, .id = "source")
# Out:
# Error in eval(expr, envir, enclos): object 'adriandix' not found
# Traceback:
